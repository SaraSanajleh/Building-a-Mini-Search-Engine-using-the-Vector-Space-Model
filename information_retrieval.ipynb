# %% [markdown]
# ## Step 1: Importing Libraries
#
# In this step, we are importing essential libraries required for text processing and calculations.

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from collections import defaultdict
import math
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Step 2: Reading and Parsing Documents
#
# In this step, we read the **Cran 1400** dataset, split the content into individual documents, and extract the relevant fields such as the document ID, title, and body text.

# %%
with open("/kaggle/input/information-ret/cran.all.1400", "r", encoding="utf-8") as f:
    content = f.read()

raw_documents = content.strip().split(".I ")[1:]
documents = []

for raw_doc in raw_documents:
    parts = raw_doc.split("\n.T\n")
    if len(parts) < 2:
        continue

    doc_id = parts[0].strip()
    body_parts = parts[1].split("\n.W\n")
    if len(body_parts) < 2:
        continue

    title = body_parts[0].strip()
    body = body_parts[1].strip()

    full_text = title + " " + body
    documents.append({
        "id": doc_id,
        "text": full_text
    })

print(f"Number of documents: {len(documents)}")
print("Example document:\n", documents[0])
# Out:
# Number of documents: 1400
# Example document:
#  {'id': '1', 'text': 'experimental investigation of the aerodynamics of a\nwing in a slipstream .\n.A\nbrenckman,m.\n.B\nj. ae. scs. 25, 1958, 324. experimental investigation of the aerodynamics of a\nwing in a slipstream .\n  an experimental study of a wing in a propeller slipstream was\nmade in order to determine the spanwise distribution of the lift\nincrease due to slipstream at different angles of attack of the wing\nand at different free stream to slipstream velocity ratios .  the\nresults were intended in part as an evaluation basis for different\ntheoretical treatments of this problem .\n  the comparative span loading curves, together with\nsupporting evidence, showed that a substantial part of the lift increment\nproduced by the slipstream was due to a /destalling/ or\nboundary-layer-control effect .  the integrated remaining lift\nincrement, after subtracting this destalling lift, was found to agree\nwell with a potential flow theory .\n  an empirical evaluation of the destalling effects was made for\nthe specific configuration of the experiment .'}

# %% [markdown]
# ## Step 3: Preprocessing the Documents
#
# In this step, we perform text preprocessing on each document.

# %%
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

def preprocess(text):
    text = text.lower()
    tokens = word_tokenize(text)
    tokens = [token for token in tokens if token.isalpha()]
    tokens = [token for token in tokens if token not in stop_words]
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

for doc in documents:
    doc["tokens"] = preprocess(doc["text"])

print("Sample tokens from the first document:", documents[0]["tokens"][:20])
# Out:
# Sample tokens from the first document: ['experiment', 'investig', 'aerodynam', 'wing', 'slipstream', 'brenckman', 'ae', 'sc', 'experiment', 'investig', 'aerodynam', 'wing', 'slipstream', 'experiment', 'studi', 'wing', 'propel', 'slipstream', 'made', 'order']

# %% [markdown]
# ## Step 4: Building the Inverted Index
#
# In this step, we build the **inverted index** which maps each term to:
# - The list of documents where the term appears.
# - The **term frequency (TF)** in each document.
#
# The **inverted index** helps in quickly identifying which documents contain which terms, and how often each term appears in those documents.

# %%
inverted_index = defaultdict(lambda: defaultdict(int))

for doc in documents:
    doc_id = doc["id"]
    tokens = doc["tokens"]

    for token in tokens:
        inverted_index[token][doc_id] += 1

sample_term = list(inverted_index.keys())[0]
print(f"Sample inverted index for the term '{sample_term}':", inverted_index[sample_term])
# Out:
# Sample inverted index for the term 'experiment': defaultdict(<class 'int'>, {'1': 3, '11': 1, '12': 1, '16': 1, '17': 1, '19': 1, '25': 1, '29': 1, '30': 2, '35': 1, '37': 1, '41': 1, '43': 1, '47': 1, '52': 2, '53': 1, '58': 1, '69': 1, '70': 1, '74': 2, '78': 2, '84': 3, '99': 2, '101': 1, '103': 1, '112': 1, '115': 1, '121': 1, '123': 3, '131': 1, '137': 1, '140': 1, '142': 1, '154': 1, '156': 1, '167': 1, '168': 1, '170': 1, '171': 2, '173': 2, '176': 1, '179': 2, '183': 1, '184': 1, '186': 3, '187': 1, '188': 1, '189': 2, '191': 1, '195': 3, '197': 2, '202': 1, '203': 1, '206': 2, '207': 2, '212': 1, '216': 1, '220': 1, '222': 1, '225': 2, '227': 1, '230': 1, '234': 4, '245': 1, '251': 1, '256': 3, '257': 1, '262': 1, '271': 3, '273': 1, '277': 1, '282': 1, '283': 1, '286': 1, '287': 1, '289': 1, '294': 1, '295': 1, '304': 1, '307': 1, '329': 2, '330': 2, '334': 2, '338': 1, '339': 2, '344': 3, '345': 1, '346': 3, '347': 1, '354': 1, '360': 1, '369': 1, '370': 1, '372': 3, '377': 1, '397': 1, '409': 1, '411': 2, '413': 2, '418': 1, '420': 2, '421': 1, '423': 2, '427': 1, '433': 1, '435': 1, '439': 1, '441': 2, '442': 3, '443': 1, '453': 1, '455': 2, '462': 1, '464': 1, '467': 1, '484': 3, '494': 2, '496': 1, '497': 2, '498': 1, '501': 1, '503': 1, '504': 1, '505': 1, '511': 1, '517': 1, '518': 2, '519': 1, '520': 2, '522': 3, '536': 1, '540': 1, '544': 3, '549': 2, '552': 2, '553': 1, '558': 2, '563': 1, '567': 1, '569': 2, '572': 4, '576': 1, '588': 1, '595': 1, '600': 1, '606': 1, '610': 1, '632': 1, '634': 1, '635': 1, '636': 1, '644': 1, '645': 1, '649': 1, '658': 1, '662': 2, '663': 2, '666': 2, '670': 1, '675': 1, '678': 1, '679': 1, '685': 3, '688': 4, '689': 2, '694': 1, '704': 2, '712': 1, '713': 1, '717': 1, '720': 1, '725': 1, '728': 1, '729': 1, '739': 1, '740': 1, '743': 1, '753': 1, '760': 3, '764': 1, '766': 4, '767': 3, '772': 3, '781': 2, '790': 1, '801': 3, '802': 1, '806': 1, '816': 2, '820': 1, '823': 2, '825': 1, '827': 2, '830': 1, '836': 5, '844': 1, '845': 2, '846': 1, '847': 2, '856': 4, '857': 3, '858': 3, '863': 2, '866': 2, '867': 1, '869': 1, '878': 2, '881': 1, '887': 1, '891': 2, '907': 1, '911': 2, '912': 2, '923': 1, '924': 1, '927': 3, '928': 3, '932': 2, '935': 2, '946': 2, '950': 4, '951': 1, '954': 2, '955': 1, '959': 1, '961': 1, '964': 1, '965': 1, '973': 1, '974': 1, '984': 2, '986': 4, '996': 1, '997': 4, '999': 1, '1006': 1, '1008': 1, '1016': 1, '1019': 3, '1028': 1, '1039': 3, '1040': 1, '1045': 1, '1046': 1, '1049': 2, '1051': 1, '1062': 3, '1066': 4, '1069': 1, '1070': 1, '1074': 3, '1075': 3, '1076': 1, '1078': 1, '1080': 1, '1081': 1, '1082': 1, '1083': 1, '1092': 1, '1097': 3, '1098': 2, '1110': 1, '1112': 1, '1118': 2, '1122': 2, '1125': 1, '1127': 1, '1145': 1, '1146': 1, '1151': 1, '1153': 1, '1155': 2, '1156': 3, '1158': 1, '1159': 2, '1160': 2, '1161': 2, '1167': 2, '1171': 1, '1172': 1, '1177': 1, '1185': 1, '1186': 1, '1187': 1, '1192': 1, '1195': 1, '1196': 2, '1198': 1, '1199': 1, '1204': 3, '1205': 1, '1209': 3, '1212': 1, '1213': 2, '1214': 3, '1216': 1, '1218': 2, '1220': 1, '1222': 1, '1225': 3, '1227': 1, '1228': 1, '1230': 1, '1231': 1, '1234': 1, '1237': 1, '1261': 1, '1262': 1, '1263': 2, '1264': 2, '1268': 1, '1269': 2, '1277': 2, '1290': 1, '1298': 1, '1302': 2, '1310': 1, '1314': 2, '1317': 1, '1319': 1, '1324': 1, '1337': 3, '1338': 2, '1339': 1, '1341': 1, '1352': 2, '1363': 2, '1364': 2, '1369': 1, '1372': 1, '1374': 1, '1378': 1, '1384': 1, '1390': 1, '1392': 1, '1396': 1, '1397': 1})

# %% [markdown]
# ## Step 5: Calculating TF-IDF
#
# In this step, we calculate the **TF-IDF (Term Frequency - Inverse Document Frequency)** for each term in each document.
#
# - **TF (Term Frequency)**: Measures how frequently a term appears in a document.
# - **IDF (Inverse Document Frequency)**: Measures how important a term is across all documents. If a term appears in many documents, its IDF will be lower.

# %%
def calculate_idf(term, total_docs):
    doc_count = len(inverted_index[term])
    if doc_count == 0:
        return 0
    return math.log(total_docs / doc_count)

def calculate_tfidf(documents, inverted_index):
    total_docs = len(documents)
    tfidf_scores = {}

    for term in inverted_index:
        idf = calculate_idf(term, total_docs)
        for doc_id, tf in inverted_index[term].items():
            if doc_id not in tfidf_scores:
                tfidf_scores[doc_id] = {}
            tfidf_scores[doc_id][term] = tf * idf
    return tfidf_scores

tfidf_scores = calculate_tfidf(documents, inverted_index)

print(f"Sample TF-IDF for document 1: {tfidf_scores['1']}")
# Out:
# Sample TF-IDF for document 1: {'experiment': 4.2724337557529655, 'investig': 2.710699114540938, 'aerodynam': 4.147487041130396, 'wing': 7.4757964316767405, 'slipstream': 28.075668948850883, 'brenckman': 7.24422751560335, 'ae': 1.520642413650969, 'sc': 1.4390925466868614, 'studi': 1.7719568419318754, 'propel': 3.912023005428146, 'made': 2.7611926800105056, 'order': 2.2335922215070942, 'determin': 1.5437839422126636, 'spanwis': 4.02535169073515, 'distribut': 1.3609051271150712, 'lift': 9.181870500900727, 'increas': 1.916351346813769, 'due': 4.576800916004179, 'differ': 5.9758622626701605, 'angl': 1.9409226075442743, 'attack': 2.571398681141444, 'free': 2.5998366164619773, 'stream': 2.2137895942109145, 'veloc': 1.5076552181241583, 'ratio': 1.5882357047834974, 'result': 0.70608769183568, 'intend': 4.75932086581535, 'part': 5.180534330891653, 'evalu': 5.991464547107982, 'basi': 3.0247198104272432, 'theoret': 1.784642001459191, 'treatment': 3.5306554488990423, 'problem': 1.4665751923806936, 'compar': 1.7348391789753728, 'span': 3.876931685616876, 'load': 1.9763693565400218, 'curv': 2.5080290672088545, 'togeth': 3.5553480614894135, 'support': 3.0545727735769246, 'evid': 3.7178669909871886, 'show': 1.9409226075442743, 'substanti': 3.5306554488990423, 'increment': 8.822028343094267, 'produc': 2.913494175317019, 'effect': 1.9164588421889706, 'integr': 2.2744142160273495, 'remain': 3.332204510175204, 'subtract': 6.551080335043404, 'destal': 13.102160670086809, 'found': 1.4696759700589417, 'agre': 3.1666900716976305, 'well': 2.2335922215070942, 'potenti': 3.2188758248682006, 'flow': 0.6733445532637655, 'theori': 1.1305453357711188, 'empir': 3.986130977581868, 'specif': 3.1498829533812494, 'configur': 2.849778360930911, 'experi': 2.2203469947570738}

# %%
def get_query_tfidf(query, inverted_index, tfidf_scores):
    tokens = preprocess(query)
    tf_query = defaultdict(int)

    for token in tokens:
        tf_query[token] += 1

    total_docs = len(tfidf_scores)

    query_tfidf = {}
    for term, tf in tf_query.items():
        doc_count = len(inverted_index.get(term, {}))
        if doc_count == 0:
            idf = 0
        else:
            idf = math.log(total_docs / doc_count)
        query_tfidf[term] = tf * idf

    return query_tfidf

# %% [markdown]
# ## Step 6: Calculating Cosine Similarity
#
# In this step, we calculate the **Cosine Similarity** between the query and each document. Cosine similarity is a metric used to measure how similar two vectors are, by calculating the cosine of the angle between them.

# %%
def cosine_similarity(query_tfidf, doc_tfidf):
    dot_product = sum(query_tfidf.get(term, 0) * doc_tfidf.get(term, 0) for term in query_tfidf)

    query_magnitude = math.sqrt(sum(value**2 for value in query_tfidf.values()))
    doc_magnitude = math.sqrt(sum(value**2 for value in doc_tfidf.values()))

    if query_magnitude == 0 or doc_magnitude == 0:
        return 0

    return dot_product / (query_magnitude * doc_magnitude)

query = "aerodynamics of wing"
query_tokens = preprocess(query)
query_tfidf = {term: tfidf_scores['1'].get(term, 0) for term in query_tokens}

similarity = cosine_similarity(query_tfidf, tfidf_scores['1'])
print(f"Cosine similarity between query and document 1: {similarity}")
# Out:
# Cosine similarity between query and document 1: 0.20443306891784382

# %%
def rank_documents(query):
    query_tfidf = get_query_tfidf(query, inverted_index, tfidf_scores)

    similarities = []

    for doc_id in tfidf_scores:
        similarity = cosine_similarity(query_tfidf, tfidf_scores[doc_id])
        similarities.append((doc_id, similarity))

    similarities.sort(key=lambda x: x[1], reverse=True)

    return similarities[:10]

# %% [markdown]
# ## Step 7: Handling User Input for Multiple Queries
#
# In this step, we allow the user to input **multiple queries** (The number of queries he wants by changing the parameter in the for loop). The user will be prompted to enter each query, and the engine will test the search engine's functionality by processing these queries.
#
# For each query entered, the engine will rank the top documents based on their **Cosine Similarity** to the query.

# %%
def test_multiple_user_inputs():
    queries = []

    print("Please enter search queries:")
    for i in range(1, 3):
        query = input(f"Enter query {i}: ")
        queries.append(query)

    for query in queries:
        print(f"Testing query: {query}")
        top_documents = rank_documents(query)
        for doc_id, similarity in top_documents:
            print(f"Document {doc_id} - Similarity: {similarity}")
        print("-" * 50)

test_multiple_user_inputs()
# Out:
# Please enter search queries:
# Enter query 1:  aeroelastic problems
# Enter query 2:  slender conical wings
# Testing query: aeroelastic problems
# Document 746 - Similarity: 0.5162829056599343
# Document 875 - Similarity: 0.34890303298886677
# Document 781 - Similarity: 0.24123787275371236
# Document 12 - Similarity: 0.22877521283067803
# Document 14 - Similarity: 0.21428828154357907
# Document 685 - Similarity: 0.17268928451467708
# Document 284 - Similarity: 0.16395843169681382
# Document 141 - Similarity: 0.15026406258008437
# Document 1361 - Similarity: 0.14046464118688892
# Document 390 - Similarity: 0.12201489530958481
# --------------------------------------------------
# Testing query: slender conical wings
# Document 633 - Similarity: 0.4006985119440997
# Document 752 - Similarity: 0.3740413963481433
# Document 683 - Similarity: 0.3221847744750085
# Document 513 - Similarity: 0.32130820053841525
# Document 1070 - Similarity: 0.3194540592510208
# Document 1058 - Similarity: 0.2908455156213503
# Document 601 - Similarity: 0.2880270341369228
# Document 465 - Similarity: 0.27946546679755213
# Document 680 - Similarity: 0.2733836491253378
# Document 688 - Similarity: 0.2667954728556031
# --------------------------------------------------

# %% [markdown]
# ## Step 8: Reading Queries from cran.qry
#
# In this step, we read the queries from the **cran.qry** file, which contains predefined queries. Each query is processed to extract the query text and then tested using the search engine.

# %%
queries = []

with open("/kaggle/input/information-ret/cran.qry", "r", encoding="utf-8") as f:
    content = f.read()

raw_queries = content.strip().split(".I ")[1:]

for raw_query in raw_queries:
    parts = raw_query.split("\n.W\n")
    if len(parts) < 2:
        continue

    query_id = parts[0].strip()
    query_text = parts[1].strip()

    queries.append({
        "id": query_id,
        "query": query_text
    })

for query in queries:
    query_text = query["query"]
    print(f"Testing query: {query_text}")
    processed_query_tokens = preprocess(query_text)
    top_documents = rank_documents(query_text)
    for doc_id, similarity in top_documents:
        print(f"Document {doc_id} - Similarity: {similarity}")
    print("-" * 50)
# Out:
# Testing query: what similarity laws must be obeyed when constructing aeroelastic models
# of heated high speed aircraft .
# Document 51 - Similarity: 0.2705118029810288
# Document 746 - Similarity: 0.24020465925891124
# Document 359 - Similarity: 0.20846121267541776
# Document 875 - Similarity: 0.18525992743688613
# Document 13 - Similarity: 0.1794288024366314
# Document 56 - Similarity: 0.17942148554813572
# Document 12 - Similarity: 0.17638242504480664
# Document 486 - Similarity: 0.14833458942226246
# Document 584 - Similarity: 0.14083125315903686
# Document 685 - Similarity: 0.13971730958454948
# --------------------------------------------------
# Testing query: what are the structural and aeroelastic problems associated with flight
# of high speed aircraft .
# Document 12 - Similarity: 0.4579373478031025
# Document 746 - Similarity: 0.40526811530518575
# Document 51 - Similarity: 0.32788591691126917
# Document 875 - Similarity: 0.24770325140724356
# Document 100 - Similarity: 0.2059761779971445
# Document 1169 - Similarity: 0.20180938398666418
# Document 884 - Similarity: 0.1955939155069759
# Document 497 - Similarity: 0.1952851462078029
# Document 47 - Similarity: 0.19349631126490363
# Document 253 - Similarity: 0.19300028007667017
# --------------------------------------------------
# Testing query: what problems of heat conduction in composite slabs have been solved so
# far .
# Document 485 - Similarity: 0.6269980763560071
# Document 90 - Similarity: 0.4633182477995237
# Document 5 - Similarity: 0.45327654963258135
# Document 144 - Similarity: 0.4373292796949892
# Document 399 - Similarity: 0.4286681283931183
# Document 91 - Similarity: 0.42255450923937415
# Document 582 - Similarity: 0.30073258135308606
# Document 6 - Similarity: 0.25646408720510905
# Document 181 - Similarity: 0.21386684715541163
# Document 579 - Similarity: 0.1612799091188162
# --------------------------------------------------
# Testing query: can a criterion be developed to show empirically the validity of flow
# solutions for chemically reacting gas mixtures based on the simplifying
# assumption of instantaneous local chemical equilibrium .
# Document 488 - Similarity: 0.370668350090287
# Document 166 - Similarity: 0.36815731727110323
# Document 1061 - Similarity: 0.24030581956147015
# Document 410 - Similarity: 0.23068147810300726
# Document 1275 - Similarity: 0.19165175459518602
# Document 167 - Similarity: 0.18922772175550295
# Document 185 - Similarity: 0.1858031364111671
# Document 575 - Similarity: 0.16348078291631468
# Document 1252 - Similarity: 0.16317981979995755
# Document 1189 - Similarity: 0.15498634414660695
# --------------------------------------------------
# Testing query: what chemical kinetic system is applicable to hypersonic aerodynamic
# problems .
# Document 103 - Similarity: 0.2623407861508055
# Document 552 - Similarity: 0.24814660717367962
# Document 410 - Similarity: 0.1990355303117334
# Document 1032 - Similarity: 0.19764194050389533
# Document 401 - Similarity: 0.1687730801247532
# Document 367 - Similarity: 0.1660902704165651
# Document 943 - Similarity: 0.15412347969025164
# Document 1061 - Similarity: 0.1540002470890732
# Document 488 - Similarity: 0.14806092573405216
# Document 26 - Similarity: 0.14489770266312405
# --------------------------------------------------
# Testing query: what theoretical and experimental guides do we have as to turbulent
# couette flow behaviour .
# Document 386 - Similarity: 0.29903582922930877
# Document 385 - Similarity: 0.28903428857116625
# Document 491 - Similarity: 0.27460760667463946
# Document 1273 - Similarity: 0.22587054867301376
# Document 406 - Similarity: 0.17759356458878223
# Document 1282 - Similarity: 0.15559680138752688
# Document 1308 - Similarity: 0.1525619304406296
# Document 257 - Similarity: 0.14238769950340358
# Document 99 - Similarity: 0.14098460793988202
# Document 151 - Similarity: 0.1373897206159538
# --------------------------------------------------
# Testing query: is it possible to relate the available pressure distributions for an
# ogive forebody at zero angle of attack to the lower surface pressures of
# an equivalent ogive forebody at angle of attack .
# Document 492 - Similarity: 0.5359524170152259
# Document 434 - Similarity: 0.31920744772092163
# Document 57 - Similarity: 0.290887207410597
# Document 233 - Similarity: 0.27798441284743525
# Document 1040 - Similarity: 0.2682654396169009
# Document 56 - Similarity: 0.24047909451554597
# Document 759 - Similarity: 0.23085252474973839
# Document 124 - Similarity: 0.22964111871770376
# Document 232 - Similarity: 0.20682141998827192
# Document 354 - Similarity: 0.19832703776643532
# --------------------------------------------------
# Testing query: what methods -dash exact or approximate -dash are presently available
# for predicting body pressures at angle of attack.
# Document 492 - Similarity: 0.4700977118961575
# Document 122 - Similarity: 0.3495960073341732
# Document 234 - Similarity: 0.3084663004803487
# Document 1307 - Similarity: 0.30614371370843585
# Document 354 - Similarity: 0.29921949063444636
# Document 69 - Similarity: 0.29252544897122995
# Document 1231 - Similarity: 0.28409229752138004
# Document 248 - Similarity: 0.2718707766922723
# Document 48 - Similarity: 0.25521266785316676
# Document 1115 - Similarity: 0.2502392499208217
# --------------------------------------------------
# Testing query: papers on internal /slip flow/ heat transfer studies .
# Document 102 - Similarity: 0.3270866902332652
# Document 763 - Similarity: 0.32531390653197906
# Document 846 - Similarity: 0.3174647732837416
# Document 45 - Similarity: 0.31121741088928834
# Document 398 - Similarity: 0.2945023066530224
# Document 5 - Similarity: 0.2863249900415205
# Document 554 - Similarity: 0.23808838862669746
# Document 872 - Similarity: 0.20098564494947005
# Document 123 - Similarity: 0.19846968036851287
# Document 303 - Similarity: 0.19662955621875908
# --------------------------------------------------
# Testing query: are real-gas transport properties for air available over a wide range of
# enthalpies and densities .
# Document 302 - Similarity: 0.40855613422333664
# Document 949 - Similarity: 0.3194695788024172
# Document 493 - Similarity: 0.2998715418267242
# Document 1098 - Similarity: 0.21784247406351495
# Document 524 - Similarity: 0.21347455431616236
# Document 1199 - Similarity: 0.21228136369086323
# Document 616 - Similarity: 0.2005902071180817
# Document 1214 - Similarity: 0.19824644782008788
# Document 691 - Similarity: 0.19281904041885178
# Document 1150 - Similarity: 0.17172527788551878
# --------------------------------------------------
# Testing query: is it possible to find an analytical,  similar solution of the strong
# blast wave problem in the newtonian approximation .
# Document 495 - Similarity: 0.6291895326516905
# Document 654 - Similarity: 0.29316198353327566
# Document 556 - Similarity: 0.2847315802511058
# Document 1327 - Similarity: 0.27155145716520135
# Document 738 - Similarity: 0.22289529936887034
# Document 1186 - Similarity: 0.1915462986183852
# Document 472 - Similarity: 0.18799875147215991
# Document 1356 - Similarity: 0.1875281957994974
# Document 557 - Similarity: 0.1808853016320342
# Document 305 - Similarity: 0.1751737723480487
# --------------------------------------------------
# Testing query: how can the aerodynamic performance of channel flow ground effect
# machines be calculated .
# Document 941 - Similarity: 0.4363890725640263
# Document 624 - Similarity: 0.297442823382085
# Document 1221 - Similarity: 0.27840893536502803
# Document 966 - Similarity: 0.2748210540662739
# Document 1223 - Similarity: 0.26628578051793084
# Document 270 - Similarity: 0.25700074697764663
# Document 652 - Similarity: 0.23630064634899686
# Document 34 - Similarity: 0.23507357574365492
# Document 1222 - Similarity: 0.22061504428590684
# Document 245 - Similarity: 0.21947847713734578
# --------------------------------------------------
# Testing query: what is the basic mechanism of the transonic aileron buzz .
# Document 496 - Similarity: 0.6876983706620473
# Document 903 - Similarity: 0.25230367804520926
# Document 643 - Similarity: 0.20620087218727715
# Document 313 - Similarity: 0.20121068503296133
# Document 199 - Similarity: 0.19843416684237067
# Document 801 - Similarity: 0.14685340613397993
# Document 503 - Similarity: 0.14331303121495587
# Document 468 - Similarity: 0.1380402055876126
# Document 507 - Similarity: 0.1375129953713175
# Document 526 - Similarity: 0.13098113018514668
# --------------------------------------------------
# Testing query: papers on shock-sound wave interaction .
# Document 170 - Similarity: 0.46034335112190067
# Document 798 - Similarity: 0.3875625636467057
# Document 256 - Similarity: 0.3732818802281829
# Document 345 - Similarity: 0.37261163602441916
# Document 1364 - Similarity: 0.3667894345798306
# Document 335 - Similarity: 0.3518009448780965
# Document 64 - Similarity: 0.331962157242575
# Document 291 - Similarity: 0.29002341657554437
# Document 973 - Similarity: 0.28097407980722927
# Document 569 - Similarity: 0.26382724811660363
# --------------------------------------------------
# Testing query: material properties of photoelastic materials .
# Document 462 - Similarity: 0.3639271146630082
# Document 1097 - Similarity: 0.19803701322482398
# Document 761 - Similarity: 0.1845183942915535
# Document 1096 - Similarity: 0.18385371739863599
# Document 463 - Similarity: 0.170486456623528
# Document 1025 - Similarity: 0.16881428868544876
# Document 866 - Similarity: 0.16744501160027261
# Document 553 - Similarity: 0.16620363833674992
# Document 1117 - Similarity: 0.14940660053981844
# Document 1098 - Similarity: 0.14249643755164842
# --------------------------------------------------
# Testing query: can the transverse potential flow about a body of revolution be
# calculated efficiently by an electronic computer .
# Document 498 - Similarity: 0.40799558230914595
# Document 106 - Similarity: 0.3983646400270956
# Document 231 - Similarity: 0.2597474868824413
# Document 1328 - Similarity: 0.2519976328750456
# Document 248 - Similarity: 0.21559420710251725
# Document 1301 - Similarity: 0.21152905227243607
# Document 1255 - Similarity: 0.20714230705921882
# Document 1112 - Similarity: 0.1952709826671347
# Document 494 - Similarity: 0.19466513949666145
# Document 814 - Similarity: 0.19434572203820819
# --------------------------------------------------
# Testing query: can the three-dimensional problem of a transverse potential flow about
# a body of revolution be reduced to a two-dimensional problem .
# Document 106 - Similarity: 0.5060859760458704
# Document 498 - Similarity: 0.3692069784649983
# Document 1301 - Similarity: 0.27820341015271227
# Document 1108 - Similarity: 0.2756365052873635
# Document 231 - Similarity: 0.23920370436368463
# Document 494 - Similarity: 0.23879457988244593
# Document 814 - Similarity: 0.23162612028545898
# Document 384 - Similarity: 0.22882416838944797
# Document 410 - Similarity: 0.22685813476091615
# Document 326 - Similarity: 0.21599605580027326
# --------------------------------------------------
# Testing query: are experimental pressure distributions on bodies of revolution at angle
# of attack available .
# Document 248 - Similarity: 0.434945986367018
# Document 492 - Similarity: 0.40743977608004595
# Document 197 - Similarity: 0.39209419565113185
# Document 498 - Similarity: 0.3567417355352352
# Document 354 - Similarity: 0.30972564522355095
# Document 1301 - Similarity: 0.3011151643775391
# Document 231 - Similarity: 0.29790106707885633
# Document 234 - Similarity: 0.2958529833744612
# Document 56 - Similarity: 0.28966380924131646
# Document 106 - Similarity: 0.28939465879607124
# --------------------------------------------------
# Testing query: does there exist a good basic treatment of the dynamics of re-entry
# combining consideration of realistic effects with relative simplicity of
# results .
# Document 803 - Similarity: 0.13685787678466996
# Document 1242 - Similarity: 0.13078996634159532
# Document 660 - Similarity: 0.11805160049870952
# Document 303 - Similarity: 0.11398379091466877
# Document 1006 - Similarity: 0.11006288793691589
# Document 286 - Similarity: 0.10702907284258106
# Document 434 - Similarity: 0.10137745931613387
# Document 1005 - Similarity: 0.10134239348824522
# Document 987 - Similarity: 0.10103777936037506
# Document 706 - Similarity: 0.09971700122766342
# --------------------------------------------------
# Testing query: has anyone formally determined the influence of joule heating,  produced
# by the induced current,  in magnetohydrodynamic free convection flows
# under general conditions .
# Document 500 - Similarity: 0.5602474803485634
# Document 270 - Similarity: 0.19199897039894265
# Document 104 - Similarity: 0.16177329805853227
# Document 87 - Similarity: 0.15875704812275443
# Document 450 - Similarity: 0.15511748707565406
# Document 607 - Similarity: 0.15389198958473058
# Document 963 - Similarity: 0.15313699672627876
# Document 268 - Similarity: 0.15148492033146768
# Document 407 - Similarity: 0.1499016154665048
# Document 88 - Similarity: 0.14587398618021893
# --------------------------------------------------
# Testing query: why does the compressibility transformation fail to correlate the high
# speed data for helium and air .
# Document 502 - Similarity: 0.338928863683349
# Document 16 - Similarity: 0.2806680108029687
# Document 68 - Similarity: 0.26166814070867195
# Document 377 - Similarity: 0.26046536000679393
# Document 1007 - Similarity: 0.25469870153953306
# Document 271 - Similarity: 0.23950054244485786
# Document 413 - Similarity: 0.23060697902556915
# Document 686 - Similarity: 0.2228102472137398
# Document 628 - Similarity: 0.218575500633825
# Document 376 - Similarity: 0.2140915599217006
# --------------------------------------------------
# Testing query: did anyone else discover that the turbulent skin friction is not over
# sensitive to the nature of the variation of the viscosity with
# temperature .
# Document 125 - Similarity: 0.2639841211826028
# Document 254 - Similarity: 0.24005198122200777
# Document 413 - Similarity: 0.23891735000005745
# Document 346 - Similarity: 0.2384031543844751
# Document 560 - Similarity: 0.2277574330071388
# Document 140 - Similarity: 0.21496995734372568
# Document 207 - Similarity: 0.19497908658689692
# Document 655 - Similarity: 0.18209563883431507
# Document 260 - Similarity: 0.1811880425425805
# Document 145 - Similarity: 0.18061442052803822
# --------------------------------------------------
# Testing query: what progress has been made in research on unsteady aerodynamics .
# Document 892 - Similarity: 0.4138929664231065
# Document 899 - Similarity: 0.3574253639314827
# Document 1259 - Similarity: 0.26664597659175443
# Document 1109 - Similarity: 0.25492709438661254
# Document 903 - Similarity: 0.2080905479719936
# Document 586 - Similarity: 0.19392762905836539
# Document 1287 - Similarity: 0.17307124796798948
# Document 530 - Similarity: 0.1717654381762694
# Document 902 - Similarity: 0.1668502484606477
# Document 1112 - Similarity: 0.16352568684015698
# --------------------------------------------------
# Testing query: what are the factors which influence the time required to invert large
# structural matrices .
# Document 756 - Similarity: 0.3615862916690949
# Document 46 - Similarity: 0.3371696498210779
# Document 612 - Similarity: 0.2960369245010981
# Document 833 - Similarity: 0.2509814690234606
# Document 47 - Similarity: 0.16549896122885122
# Document 12 - Similarity: 0.15651610800368063
# Document 1034 - Similarity: 0.1492453972794035
# Document 1361 - Similarity: 0.12828404199996307
# Document 834 - Similarity: 0.12082828515501107
# Document 334 - Similarity: 0.11793455707798128
# --------------------------------------------------
# Testing query: does a practical flow follow the theoretical concepts for the
# interaction between adjacent blade rows of a supersonic cascade .
# Document 277 - Similarity: 0.44218009424297805
# Document 214 - Similarity: 0.3824637499931483
# Document 772 - Similarity: 0.2592035688820349
# Document 990 - Similarity: 0.22899504200661555
# Document 987 - Similarity: 0.22293397596707704
# Document 215 - Similarity: 0.18348453238500936
# Document 216 - Similarity: 0.18028045017928535
# Document 540 - Similarity: 0.17341422156415842
# Document 213 - Similarity: 0.16180316816205265
# Document 511 - Similarity: 0.15643977758082434
# --------------------------------------------------
# Testing query: what is a single approximate formula for the displacement thickness of
# a laminar boundary layer in compressible flow on a flat plate .
# Document 307 - Similarity: 0.3660832279125361
# Document 145 - Similarity: 0.3623787722901077
# Document 611 - Similarity: 0.35189223770886024
# Document 4 - Similarity: 0.3240835251092843
# Document 348 - Similarity: 0.31172872436148524
# Document 1076 - Similarity: 0.3083135176833581
# Document 1355 - Similarity: 0.30089527397532867
# Document 568 - Similarity: 0.26782837537935533
# Document 306 - Similarity: 0.26574155549098466
# Document 736 - Similarity: 0.2540745382202348
# --------------------------------------------------
# Testing query: how is the design of ring or part ring wings by linear theory affected
# by thickness .
# Document 1031 - Similarity: 0.40952677696363304
# Document 512 - Similarity: 0.22091430875608922
# Document 1176 - Similarity: 0.21822431404628256
# Document 1293 - Similarity: 0.2124766585370437
# Document 1132 - Similarity: 0.2097461372794777
# Document 1035 - Similarity: 0.20562197638035662
# Document 1129 - Similarity: 0.19935709510661842
# Document 224 - Similarity: 0.16720351197560113
# Document 680 - Similarity: 0.1583159697466755
# Document 752 - Similarity: 0.13677514704553165
# --------------------------------------------------
# Testing query: what application has the linear theory design of curved wings .
# Document 674 - Similarity: 0.25644890260534353
# Document 1051 - Similarity: 0.23794813631487166
# Document 680 - Similarity: 0.22303302924962637
# Document 921 - Similarity: 0.21156116194869382
# Document 1050 - Similarity: 0.20835536864900409
# Document 752 - Similarity: 0.20441403226784705
# Document 762 - Similarity: 0.20248526075128168
# Document 384 - Similarity: 0.20015675638812527
# Document 247 - Similarity: 0.19583142562702874
# Document 681 - Similarity: 0.18104133069166303
# --------------------------------------------------
# Testing query: what is the effect of cross sectional shape on the flow over simple
# delta wings with sharp leading edges .
# Document 465 - Similarity: 0.5435386990239162
# Document 420 - Similarity: 0.44346296638626914
# Document 250 - Similarity: 0.42013613635340613
# Document 612 - Similarity: 0.3853165529122763
# Document 900 - Similarity: 0.369651673505532
# Document 601 - Similarity: 0.33354473212997093
# Document 222 - Similarity: 0.3319595928580044
# Document 200 - Similarity: 0.31974841278196126
# Document 683 - Similarity: 0.3172186558919834
# Document 901 - Similarity: 0.316869408217343
# --------------------------------------------------
# Testing query: papers on flow visualization on slender conical wings .
# Document 602 - Similarity: 0.3077766767519671
# Document 633 - Similarity: 0.2535191377060573
# Document 752 - Similarity: 0.22599673978281445
# Document 683 - Similarity: 0.1995333894300351
# Document 513 - Similarity: 0.1941352120276487
# Document 1070 - Similarity: 0.1930149352611225
# Document 1058 - Similarity: 0.18942173649486974
# Document 601 - Similarity: 0.1808457248819493
# Document 222 - Similarity: 0.1754394089350467
# Document 465 - Similarity: 0.17297131594833254
# --------------------------------------------------
# Testing query: what size of end plate can be safely used to simulate two-dimensional
# flow conditions over a bluff cylindrical body of finite aspect ratio .
# Document 751 - Similarity: 0.3886512901233757
# Document 68 - Similarity: 0.23426814896519238
# Document 247 - Similarity: 0.16184837150802237
# Document 918 - Similarity: 0.15071182349741347
# Document 698 - Similarity: 0.14530811047317446
# Document 228 - Similarity: 0.14011996742600766
# Document 916 - Similarity: 0.13647432278353253
# Document 780 - Similarity: 0.13389937969250787
# Document 551 - Similarity: 0.12873742516072043
# Document 1153 - Similarity: 0.12411819696477687
# --------------------------------------------------
# Testing query: to find an approximate correction for thickness in slender thin-wing
# theory .
# Document 752 - Similarity: 0.43886790725006614
# Document 738 - Similarity: 0.3170561806822247
# Document 1259 - Similarity: 0.26607668011740976
# Document 491 - Similarity: 0.20594476956393978
# Document 27 - Similarity: 0.2010911387679481
# Document 192 - Similarity: 0.18899835278835192
# Document 1310 - Similarity: 0.18356597184945345
# Document 1186 - Similarity: 0.1809080919693266
# Document 714 - Similarity: 0.17977526464866342
# Document 242 - Similarity: 0.17436324901491693
# --------------------------------------------------
# Testing query: how do interference-free longitudinal stability measurements (made
# using free-flight models) compare with similar measurements made in
# a low-blockage wind tunnel .
# Document 516 - Similarity: 0.4916707676018413
# Document 431 - Similarity: 0.35103030144998626
# Document 594 - Similarity: 0.34801293398568695
# Document 808 - Similarity: 0.30127907598091025
# Document 1155 - Similarity: 0.29046106516148607
# Document 713 - Similarity: 0.28260405507513003
# Document 141 - Similarity: 0.27904743852124125
# Document 598 - Similarity: 0.26286941860394497
# Document 904 - Similarity: 0.25961616812896127
# Document 791 - Similarity: 0.25529290508796204
# --------------------------------------------------
# Testing query: have wind tunnel interference effects been investigated on a systematic
# basis .
# Document 516 - Similarity: 0.3686977785202958
# Document 431 - Similarity: 0.34334688639049554
# Document 610 - Similarity: 0.33800328368753924
# Document 1153 - Similarity: 0.3156029953509146
# Document 672 - Similarity: 0.3131028112797156
# Document 252 - Similarity: 0.305540880508998
# Document 1062 - Similarity: 0.28163013385392244
# Document 795 - Similarity: 0.2616683925906972
# Document 594 - Similarity: 0.2393411051928702
# Document 1074 - Similarity: 0.23352977495449834
# --------------------------------------------------
# Testing query: are there any papers dealing with acoustic wave propagation in reacting
# gases .
# Document 724 - Similarity: 0.26147415623374465
# Document 1244 - Similarity: 0.25412294016264014
# Document 75 - Similarity: 0.21558193588717167
# Document 488 - Similarity: 0.20992243352389434
# Document 654 - Similarity: 0.20650673079429419
# Document 1203 - Similarity: 0.2030490413871634
# Document 1327 - Similarity: 0.19789088093156806
# Document 1208 - Similarity: 0.19633047474992335
# Document 1389 - Similarity: 0.15513759266060995
# Document 1314 - Similarity: 0.1533188521598487
# --------------------------------------------------
# Testing query: has anyone investigated relaxation effects on gaseous heat transfer to a
# suddenly heated wall .
# Document 281 - Similarity: 0.22408096441885794
# Document 398 - Similarity: 0.2096715514261919
# Document 168 - Similarity: 0.20522348504979146
# Document 554 - Similarity: 0.17998824308742647
# Document 123 - Similarity: 0.17743399273139063
# Document 666 - Similarity: 0.17436594134155248
# Document 319 - Similarity: 0.1642088767889793
# Document 872 - Similarity: 0.16256446982770859
# Document 546 - Similarity: 0.16219788816388017
# Document 962 - Similarity: 0.15829398888223048
# --------------------------------------------------
# Testing query: are there any theoretical methods for predicting base pressure .
# Document 186 - Similarity: 0.29816094517232655
# Document 234 - Similarity: 0.27845708947790754
# Document 1311 - Similarity: 0.27494802164485704
# Document 176 - Similarity: 0.27062180708067046
# Document 189 - Similarity: 0.25133622645950615
# Document 179 - Similarity: 0.24595649204343317
# Document 979 - Similarity: 0.2447001426711284
# Document 188 - Similarity: 0.24248061765712856
# Document 519 - Similarity: 0.23591547898210535
# Document 173 - Similarity: 0.22009763150621656
# --------------------------------------------------
# Testing query: does transition in the hypersonic wake depend on body geometry and size
# Document 536 - Similarity: 0.32501546899428757
# Document 976 - Similarity: 0.29889556389326855
# Document 1141 - Similarity: 0.27505913232263646
# Document 272 - Similarity: 0.2491089951374815
# Document 154 - Similarity: 0.24707111142747382
# Document 294 - Similarity: 0.2331077254799005
# Document 295 - Similarity: 0.2328889962702205
# Document 1368 - Similarity: 0.2262503293242646
# Document 1264 - Similarity: 0.22607168505721995
# Document 1196 - Similarity: 0.19329556005809156
# --------------------------------------------------
# Testing query: how can one detect transition phenomena in boundary layers .
# Document 272 - Similarity: 0.2916745839888572
# Document 37 - Similarity: 0.2693237042832098
# Document 1205 - Similarity: 0.2421339123191619
# Document 1264 - Similarity: 0.23129137015835996
# Document 9 - Similarity: 0.2242405298602138
# Document 1278 - Similarity: 0.2055150310461324
# Document 113 - Similarity: 0.2019540753128757
# Document 295 - Similarity: 0.19370656888473958
# Document 1381 - Similarity: 0.18569630920309202
# Document 346 - Similarity: 0.18569540924098174
# --------------------------------------------------
# Testing query: how can one detect transition phenomena in hypersonic wakes .
# Document 536 - Similarity: 0.32552035486558156
# Document 37 - Similarity: 0.3038459592360009
# Document 272 - Similarity: 0.254947575366507
# Document 1141 - Similarity: 0.25216697450358166
# Document 976 - Similarity: 0.2368476795454087
# Document 1205 - Similarity: 0.21776079854367467
# Document 1368 - Similarity: 0.2074203482879362
# Document 295 - Similarity: 0.2045417220952279
# Document 154 - Similarity: 0.19392397467917702
# Document 294 - Similarity: 0.1824978872210482
# --------------------------------------------------
# Testing query: has anyone investigated and developed a simple model for the vortex
# wake behind a cruciform wing .
# Document 289 - Similarity: 0.626205715760836
# Document 433 - Similarity: 0.45371135688624453
# Document 432 - Similarity: 0.3704908749459444
# Document 927 - Similarity: 0.363462709519295
# Document 1141 - Similarity: 0.33989252316889157
# Document 229 - Similarity: 0.32256186520656593
# Document 154 - Similarity: 0.28211413458421986
# Document 288 - Similarity: 0.27988181081350166
# Document 126 - Similarity: 0.2512240109264209
# Document 1196 - Similarity: 0.23885669627004014
# --------------------------------------------------
# Testing query: what is a criterion that the transonic flow around an airfoil with a
# round leading edge be validly analyzed by the linearized transonic flow
# theory .
# Document 521 - Similarity: 0.5712646532957035
# Document 503 - Similarity: 0.4406030398881383
# Document 526 - Similarity: 0.4364847202907874
# Document 440 - Similarity: 0.3561300882690517
# Document 467 - Similarity: 0.34040527843852114
# Document 312 - Similarity: 0.3245828751113206
# Document 468 - Similarity: 0.32389775756659434
# Document 801 - Similarity: 0.2992459047044586
# Document 469 - Similarity: 0.2907059822514976
# Document 404 - Similarity: 0.27777040020195953
# --------------------------------------------------
# Testing query: can the transonic flow around an arbitrary smooth thin airfoil be
# analysed in a simple approximate way .
# Document 467 - Similarity: 0.3386390723383414
# Document 503 - Similarity: 0.327342822501605
# Document 194 - Similarity: 0.2881693375719828
# Document 312 - Similarity: 0.26276636825756355
# Document 404 - Similarity: 0.24721080293623926
# Document 469 - Similarity: 0.23808017400648304
# Document 39 - Similarity: 0.22302069831001514
# Document 440 - Similarity: 0.221512792968639
# Document 468 - Similarity: 0.20961809503355638
# Document 526 - Similarity: 0.20821140955171652
# --------------------------------------------------
# Testing query: what are the details of the rigorous kinetic theory of gases .
# (chapman-enskog theory) .
# Document 583 - Similarity: 0.17555535569092146
# Document 1314 - Similarity: 0.14943431701430412
# Document 385 - Similarity: 0.14593528926198768
# Document 541 - Similarity: 0.13811728527432457
# Document 1031 - Similarity: 0.12900874818066418
# Document 103 - Similarity: 0.12890080192548828
# Document 1148 - Similarity: 0.1268347773638875
# Document 862 - Similarity: 0.12494608933191276
# Document 410 - Similarity: 0.12024077680488207
# Document 1199 - Similarity: 0.11232532171289658
# --------------------------------------------------
# Testing query: has anyone investigated the effect of surface mass transfer on
# hypersonic viscous interactions .
# Document 305 - Similarity: 0.5622525329971427
# Document 525 - Similarity: 0.5188239693743321
# Document 540 - Similarity: 0.45476200265361855
# Document 1185 - Similarity: 0.3466110214739535
# Document 84 - Similarity: 0.32651241107248197
# Document 123 - Similarity: 0.32584570898106285
# Document 310 - Similarity: 0.2824432218677773
# Document 37 - Similarity: 0.27712826600105184
# Document 570 - Similarity: 0.27551498910898264
# Document 1200 - Similarity: 0.26189967930210345
# --------------------------------------------------
# Testing query: what is the combined effect of surface heat and mass transfer on
# hypersonic flow .
# Document 525 - Similarity: 0.4695280710172972
# Document 1185 - Similarity: 0.4298210563730457
# Document 123 - Similarity: 0.3914474243117053
# Document 305 - Similarity: 0.356421431189496
# Document 84 - Similarity: 0.35074702533141705
# Document 37 - Similarity: 0.30093591948239096
# Document 623 - Similarity: 0.299774132149749
# Document 803 - Similarity: 0.2864304615723403
# Document 655 - Similarity: 0.2693064954554645
# Document 398 - Similarity: 0.24832615139879155
# --------------------------------------------------
# Testing query: what are the existing solutions for hypersonic viscous interactions over
# an insulated flat plate .
# Document 568 - Similarity: 0.5574012699625622
# Document 525 - Similarity: 0.4939010910417797
# Document 305 - Similarity: 0.424661364710741
# Document 304 - Similarity: 0.4054670134240543
# Document 1200 - Similarity: 0.3445893317003453
# Document 570 - Similarity: 0.3389275083166564
# Document 540 - Similarity: 0.3345545427521062
# Document 310 - Similarity: 0.3273936019458389
# Document 663 - Similarity: 0.2731697381614364
# Document 327 - Similarity: 0.26281413925770747
# --------------------------------------------------
# Testing query: what controls leading-edge attachment at transonic speeds .
# Document 526 - Similarity: 0.5356975434136642
# Document 440 - Similarity: 0.3349167868898627
# Document 801 - Similarity: 0.2768489669146356
# Document 638 - Similarity: 0.2578734640268834
# Document 468 - Similarity: 0.25388882722615824
# Document 368 - Similarity: 0.24939701747123197
# Document 503 - Similarity: 0.24821522995257336
# Document 748 - Similarity: 0.2472787953917172
# Document 609 - Similarity: 0.23584808142292124
# Document 879 - Similarity: 0.2299262875903595
# --------------------------------------------------
# Testing query: can the three-point boundary-value problem for the blasius equation
# be integrated numerically,  using suitable transformations,  without
# iteration on the boundary conditions .
# Document 527 - Similarity: 0.44858381117964596
# Document 322 - Similarity: 0.3769324499449364
# Document 321 - Similarity: 0.3593229938441855
# Document 320 - Similarity: 0.3389989966125768
# Document 349 - Similarity: 0.3015072212982305
# Document 1087 - Similarity: 0.3014648571418906
# Document 377 - Similarity: 0.29425352228266105
# Document 832 - Similarity: 0.2711945958525395
# Document 1054 - Similarity: 0.2546424087060983
# Document 1370 - Similarity: 0.2395478931430505
# --------------------------------------------------
# Testing query: what are the effects of small amounts of gas rarefaction on the
# characteristics of the boundary layers on slender bodies of revolution .
# Document 192 - Similarity: 0.26072757967596805
# Document 1301 - Similarity: 0.2533774512776778
# Document 326 - Similarity: 0.24328172202096623
# Document 1259 - Similarity: 0.24177067164123042
# Document 1112 - Similarity: 0.23141324257572446
# Document 494 - Similarity: 0.22768745260802878
# Document 27 - Similarity: 0.18812475481729155
# Document 124 - Similarity: 0.18075009290871935
# Document 337 - Similarity: 0.1807014436207656
# Document 498 - Similarity: 0.17943284153346745
# --------------------------------------------------
# Testing query: what is the available information pertaining to boundary layers on very
# slender bodies of revolution in continuum flow (the ?transverse
# curvature  effect) .
# Document 326 - Similarity: 0.29904755814530737
# Document 494 - Similarity: 0.2961750333649106
# Document 94 - Similarity: 0.2270333177000039
# Document 1301 - Similarity: 0.22001574097685617
# Document 192 - Similarity: 0.2083606915613002
# Document 106 - Similarity: 0.20814548077917364
# Document 23 - Similarity: 0.201366457047391
# Document 1259 - Similarity: 0.201133055695046
# Document 1112 - Similarity: 0.20023410137190992
# Document 133 - Similarity: 0.1972250016776181
# --------------------------------------------------
# Testing query: what is the available information pertaining to the effect of slight
# rarefaction on boundary layer flows (the ?slip? effect) .
# Document 326 - Similarity: 0.3038835115027692
# Document 306 - Similarity: 0.27106284745339454
# Document 21 - Similarity: 0.23468103074849067
# Document 1215 - Similarity: 0.2310751653497624
# Document 528 - Similarity: 0.2092918916407059
# Document 22 - Similarity: 0.20480154688133628
# Document 629 - Similarity: 0.15197360378912317
# Document 534 - Similarity: 0.14371558741288862
# Document 1214 - Similarity: 0.1421596903476617
# Document 1204 - Similarity: 0.13091187267804988
# --------------------------------------------------
# Testing query: what investigations have been made of the flow field about a body moving
# through a rarefied,  partially ionized gas in the presence of a magnetic
# field .
# Document 208 - Similarity: 0.5112912298291238
# Document 1236 - Similarity: 0.3590443575778509
# Document 269 - Similarity: 0.35228767219525187
# Document 61 - Similarity: 0.3409123365415418
# Document 1253 - Similarity: 0.3378733542016267
# Document 267 - Similarity: 0.33641596737019175
# Document 1282 - Similarity: 0.3317304062806288
# Document 298 - Similarity: 0.31908607277110257
# Document 1221 - Similarity: 0.2836991099257015
# Document 33 - Similarity: 0.2545450778356035
# --------------------------------------------------
# Testing query: how is the heat transfer downstream of the mass transfer region effected
# by mass transfer at the nose of a blunted cone .
# Document 123 - Similarity: 0.5875686289271126
# Document 1185 - Similarity: 0.45112405219238666
# Document 84 - Similarity: 0.4451788667222238
# Document 525 - Similarity: 0.42319825429361596
# Document 666 - Similarity: 0.34114143073543685
# Document 623 - Similarity: 0.308093790462441
# Document 305 - Similarity: 0.2855845771616558
# Document 554 - Similarity: 0.2775187696189019
# Document 44 - Similarity: 0.2752907154013469
# Document 398 - Similarity: 0.27459065007381567
# --------------------------------------------------
# Testing query: to what extent can the available information for incompressible boundary
# layers be applied to problems involving compressible boundary layers .
# Document 376 - Similarity: 0.3245366199718431
# Document 4 - Similarity: 0.2995097799630355
# Document 460 - Similarity: 0.2886605848062819
# Document 1301 - Similarity: 0.2206802748114765
# Document 798 - Similarity: 0.21469272406289813
# Document 1383 - Similarity: 0.21072674987491521
# Document 1214 - Similarity: 0.20617998405513505
# Document 251 - Similarity: 0.19686840248928225
# Document 1302 - Similarity: 0.19603871935601308
# Document 562 - Similarity: 0.19287511575776534
# --------------------------------------------------
# Testing query: to what extent can readily available steady-state aerodynamic data be
# utilized to predict lifting-surface flutter characteristics .
# Document 753 - Similarity: 0.3884353680966433
# Document 878 - Similarity: 0.26561503805758185
# Document 634 - Similarity: 0.2582455429189216
# Document 202 - Similarity: 0.25399153225579624
# Document 1290 - Similarity: 0.24214010843125908
# Document 391 - Similarity: 0.22359098395930357
# Document 1339 - Similarity: 0.2172731697073402
# Document 593 - Similarity: 0.2122304574836423
# Document 441 - Similarity: 0.21053091506166616
# Document 1111 - Similarity: 0.20992127028996949
# --------------------------------------------------
# Testing query: what are the significant steady and non-steady flow characteristics
# which affect the flutter mechanism .
# Document 753 - Similarity: 0.3175387207627659
# Document 878 - Similarity: 0.29866305707871155
# Document 634 - Similarity: 0.27205839743060173
# Document 202 - Similarity: 0.2673226581430729
# Document 593 - Similarity: 0.2668047820811185
# Document 1111 - Similarity: 0.2624685406063664
# Document 1290 - Similarity: 0.25998145446498905
# Document 1338 - Similarity: 0.25788375056352547
# Document 15 - Similarity: 0.2496833576357077
# Document 391 - Similarity: 0.2388319333654454
# --------------------------------------------------
# Testing query: is it possible to determine rates of forced convective heat transfer
# from heated cylinders of non-circular cross-section,  (the fluid flow
# being along the generators) .
# Document 120 - Similarity: 0.3806442761733943
# Document 963 - Similarity: 0.37049926564528207
# Document 1104 - Similarity: 0.30543231181349034
# Document 270 - Similarity: 0.3035901333008026
# Document 873 - Similarity: 0.30132680843649834
# Document 398 - Similarity: 0.2997438441834223
# Document 1159 - Similarity: 0.27438940018176233
# Document 754 - Similarity: 0.27213620833805596
# Document 104 - Similarity: 0.2701695034314718
# Document 872 - Similarity: 0.2608849652800498
# --------------------------------------------------
# Testing query: how much is known about boundary layer flows along non-circular
# cylinders .
# Document 785 - Similarity: 0.2639679658691629
# Document 786 - Similarity: 0.24880068803077787
# Document 23 - Similarity: 0.24535462606961764
# Document 912 - Similarity: 0.2413312987343399
# Document 1046 - Similarity: 0.23916839038106552
# Document 381 - Similarity: 0.22132226856282028
# Document 261 - Similarity: 0.21738649098088045
# Document 788 - Similarity: 0.20031505213401943
# Document 105 - Similarity: 0.19762680426088605
# Document 659 - Similarity: 0.1890717209601654
# --------------------------------------------------
# Testing query: is there any simple,  but practical,  method for numerical integration
# of the mixing problem (i.e. the blasius problem with three-point
# boundary conditions) .
# Document 527 - Similarity: 0.5760222655731021
# Document 321 - Similarity: 0.47245636662796325
# Document 322 - Similarity: 0.4626250882127625
# Document 320 - Similarity: 0.42324009306271154
# Document 107 - Similarity: 0.3188762273918097
# Document 11 - Similarity: 0.3019277142769585
# Document 350 - Similarity: 0.2784596231780673
# Document 960 - Similarity: 0.2518638191523951
# Document 476 - Similarity: 0.24350284162401875
# Document 131 - Similarity: 0.23665413847577185
# --------------------------------------------------
# Testing query: does there exist a closed-form expression for the local heat transfer
# around a yawed cylinder .
# Document 564 - Similarity: 0.5355057295301487
# Document 566 - Similarity: 0.46131224937214027
# Document 1213 - Similarity: 0.43526001242850176
# Document 539 - Similarity: 0.4155967675496512
# Document 333 - Similarity: 0.3660271594790746
# Document 565 - Similarity: 0.33307954622386693
# Document 435 - Similarity: 0.30506248815745546
# Document 1159 - Similarity: 0.2896569381904417
# Document 1258 - Similarity: 0.2762813240984766
# Document 1309 - Similarity: 0.2611949963148047
# --------------------------------------------------
# Testing query: how far around a cylinder and under what conditions of flow,  if any,
# is the velocity just outside of the boundary layer a linear function of
# the distance around the cylinder .
# Document 533 - Similarity: 0.3468207246510078
# Document 483 - Similarity: 0.3217984564382204
# Document 1081 - Similarity: 0.29873859505970635
# Document 1258 - Similarity: 0.2786588313905304
# Document 785 - Similarity: 0.2765096243104281
# Document 787 - Similarity: 0.2601560606796803
# Document 1046 - Similarity: 0.25462050711798245
# Document 381 - Similarity: 0.24601675751305174
# Document 788 - Similarity: 0.23933030229454044
# Document 105 - Similarity: 0.23647611992065198
# --------------------------------------------------
# Testing query: where can i find pressure data on surfaces of swept cylinders .
# Document 738 - Similarity: 0.30609930901477644
# Document 678 - Similarity: 0.2994589623575334
# Document 204 - Similarity: 0.24247151671623465
# Document 1046 - Similarity: 0.22252829502829627
# Document 843 - Similarity: 0.22005790561158894
# Document 491 - Similarity: 0.2164792294348453
# Document 1045 - Similarity: 0.2151749190803919
# Document 420 - Similarity: 0.20191476948748732
# Document 839 - Similarity: 0.18642590994003067
# Document 1121 - Similarity: 0.18089492245184022
# --------------------------------------------------
# Testing query: can't the static deflection shapes be used in predicting flutter in
# place of vibrational shapes . if so,  can we provide a justification by
# means of an example .
# Document 52 - Similarity: 0.24040074222798405
# Document 878 - Similarity: 0.20353783478728737
# Document 593 - Similarity: 0.19938935158364351
# Document 390 - Similarity: 0.19931862913987505
# Document 753 - Similarity: 0.1919255449011085
# Document 202 - Similarity: 0.18895955442074036
# Document 15 - Similarity: 0.18716856910687965
# Document 391 - Similarity: 0.17718032905457531
# Document 1111 - Similarity: 0.17402061752217576
# Document 914 - Similarity: 0.17120430421878635
# --------------------------------------------------
# Testing query: does the boundary layer on a flat plate in a shear flow induce a
# pressure gradient .
# Document 388 - Similarity: 0.5802270322979843
# Document 4 - Similarity: 0.4461198844903705
# Document 664 - Similarity: 0.43246650819156585
# Document 393 - Similarity: 0.41544154758679164
# Document 180 - Similarity: 0.3912376444711198
# Document 3 - Similarity: 0.37940248429650886
# Document 569 - Similarity: 0.34656641987146664
# Document 389 - Similarity: 0.3348793035851328
# Document 1386 - Similarity: 0.3064107439814479
# Document 1107 - Similarity: 0.2960698467091166
# --------------------------------------------------
# Testing query: can the procedure of matching inner and outer solutions for a viscous
# flow problem be applied when the main stream is a shear flow .
# Document 128 - Similarity: 0.39493831258196793
# Document 1182 - Similarity: 0.24053634948235197
# Document 664 - Similarity: 0.23094070309833778
# Document 590 - Similarity: 0.2154362771880349
# Document 305 - Similarity: 0.2148634801854718
# Document 191 - Similarity: 0.21053573991701624
# Document 1251 - Similarity: 0.20544021642094398
# Document 1206 - Similarity: 0.18432582696857003
# Document 310 - Similarity: 0.17676034264013393
# Document 389 - Similarity: 0.1757300453185036
# --------------------------------------------------
# Testing query: can series expansions be found for the boundary layer on a flat plate in
# a shear flow .
# Document 4 - Similarity: 0.4366785492998078
# Document 664 - Similarity: 0.41627386146379725
# Document 393 - Similarity: 0.4066494649219857
# Document 180 - Similarity: 0.3829577944374507
# Document 389 - Similarity: 0.32779217776212394
# Document 3 - Similarity: 0.3111030897444459
# Document 149 - Similarity: 0.3076792454052523
# Document 1107 - Similarity: 0.28743997892596884
# Document 128 - Similarity: 0.2751346066434765
# Document 458 - Similarity: 0.26849430016384607
# --------------------------------------------------
# Testing query: what possible techniques are available for computing the injection
# distribution corresponding to an isothermal transpiration cooled
# hemisphere .
# Document 628 - Similarity: 0.4662522435305957
# Document 343 - Similarity: 0.3455085502933291
# Document 662 - Similarity: 0.3354574004099033
# Document 339 - Similarity: 0.27662227418888324
# Document 1237 - Similarity: 0.21790593700116737
# Document 661 - Similarity: 0.20958593225523525
# Document 338 - Similarity: 0.2031648732176182
# Document 974 - Similarity: 0.20093108882080465
# Document 365 - Similarity: 0.20023274462235435
# Document 125 - Similarity: 0.19968833445454484
# --------------------------------------------------
# Testing query: what is known regarding asymptotic solutions to the exact boundary layer
# equations .
# Document 105 - Similarity: 0.24249647298062815
# Document 264 - Similarity: 0.23622747690031304
# Document 1138 - Similarity: 0.2185799591493361
# Document 1383 - Similarity: 0.18371905862478213
# Document 306 - Similarity: 0.17230093317882053
# Document 664 - Similarity: 0.1719056351153669
# Document 4 - Similarity: 0.16843382192370818
# Document 292 - Similarity: 0.1543082106657709
# Document 111 - Similarity: 0.1497737821766203
# Document 365 - Similarity: 0.14860345426259694
# --------------------------------------------------
# Testing query: previous solutions to the boundary layer similarity equations .
# Document 1149 - Similarity: 0.33072034684715124
# Document 540 - Similarity: 0.3062050534073559
# Document 300 - Similarity: 0.2806293685283915
# Document 349 - Similarity: 0.2496996958923961
# Document 4 - Similarity: 0.24566571724085823
# Document 327 - Similarity: 0.23930012329230718
# Document 180 - Similarity: 0.23405722398184273
# Document 435 - Similarity: 0.22992728073083887
# Document 62 - Similarity: 0.21796197515022328
# Document 104 - Similarity: 0.20979203783195152
# --------------------------------------------------
# Testing query: experimental results on hypersonic viscous interaction .
# Document 540 - Similarity: 0.5088060711505012
# Document 305 - Similarity: 0.47120734151676713
# Document 570 - Similarity: 0.36673913432839933
# Document 170 - Similarity: 0.3438807603612214
# Document 537 - Similarity: 0.34145191065282066
# Document 310 - Similarity: 0.34066120747166995
# Document 573 - Similarity: 0.32622046755777634
# Document 1253 - Similarity: 0.3187202880844244
# Document 1299 - Similarity: 0.2992221193486425
# Document 26 - Similarity: 0.2897556705213161
# --------------------------------------------------
# Testing query: what has been done about viscous interactions in relatively low reynolds
# number flows,  particularly at high mach numbers .
# Document 1078 - Similarity: 0.22880488506027644
# Document 540 - Similarity: 0.2266115060828637
# Document 666 - Similarity: 0.19552469326337285
# Document 305 - Similarity: 0.19340984088939933
# Document 630 - Similarity: 0.19336534660202942
# Document 170 - Similarity: 0.1885900941362292
# Document 238 - Similarity: 0.18572748596514746
# Document 139 - Similarity: 0.18266914436900408
# Document 663 - Similarity: 0.18225884931410694
# Document 668 - Similarity: 0.17349932825159273
# --------------------------------------------------
# Testing query: what role does the effect of chemical reaction (particularly when out of
# equilibrium) play in the similitude laws governing hypersonic flows over
# slender aerodynamic bodies .
# Document 332 - Similarity: 0.43907266776287
# Document 573 - Similarity: 0.36992997424251395
# Document 541 - Similarity: 0.3089586360705147
# Document 577 - Similarity: 0.23647601862702536
# Document 572 - Similarity: 0.22415687157167796
# Document 552 - Similarity: 0.20163246731412995
# Document 359 - Similarity: 0.195200696001497
# Document 1061 - Similarity: 0.19339794366493485
# Document 410 - Similarity: 0.19185344946037916
# Document 401 - Similarity: 0.1873186013808668
# --------------------------------------------------
# Testing query: how significant is the possible pressure of a dissociated free stream
# with respect to the realization of hypersonic simulation in high
# enthalpy wind tunnels .
# Document 1153 - Similarity: 0.2944167985900679
# Document 68 - Similarity: 0.28769599764661097
# Document 876 - Similarity: 0.2548023272300588
# Document 625 - Similarity: 0.25250530059547915
# Document 26 - Similarity: 0.2438421092014933
# Document 656 - Similarity: 0.22967631719948187
# Document 317 - Similarity: 0.20889180875985908
# Document 1295 - Similarity: 0.19694560985852022
# Document 576 - Similarity: 0.19516408559910703
# Document 1161 - Similarity: 0.18740128529487654
# --------------------------------------------------
# Testing query: do the discrepancies among current analyses of the vorticity effect
# on stagnation-point heat transfer result primarily from the
# differences in the viscosity-temperature law assumed .
# Document 584 - Similarity: 0.17508531751984202
# Document 629 - Similarity: 0.1612806417375249
# Document 902 - Similarity: 0.16127030825034236
# Document 324 - Similarity: 0.14974517769087065
# Document 323 - Similarity: 0.13847211519355682
# Document 1146 - Similarity: 0.13482771892091058
# ...
# Document 1245 - Similarity: 0.20362216021461246
# Document 541 - Similarity: 0.20119884898559198
# Document 410 - Similarity: 0.18827720396935332
# Document 578 - Similarity: 0.1792136713818459
# Document 24 - Similarity: 0.17305687992777724
# Document 1210 - Similarity: 0.1681226526911422
# Document 972 - Similarity: 0.16633873892524645
# Document 574 - Similarity: 0.1608059220463122
# --------------------------------------------------
# Testing query: how accurate are existing analytical theories in estimating pressure
# distributions on cones at incidence,  at hypersonic speeds .
# Document 1285 - Similarity: 0.47645253595486775
# Document 605 - Similarity: 0.2988492825843344
# Document 1303 - Similarity: 0.24545519760136522
# Document 1310 - Similarity: 0.232084187195244
# Document 232 - Similarity: 0.22634952542144088
# Document 423 - Similarity: 0.2226690158603987
# Document 225 - Similarity: 0.2213255428643592
# Document 1231 - Similarity: 0.21602695683893158
# Document 1378 - Similarity: 0.20284550554507316
# Document 48 - Similarity: 0.19805440537018018
# --------------------------------------------------
# Testing query: are simple empirical methods of any use for estimating pressure
# distribution in cones .
# Document 38 - Similarity: 0.37569207111962555
# Document 1285 - Similarity: 0.2976965614660256
# Document 58 - Similarity: 0.2616848044857268
# Document 225 - Similarity: 0.2571179465558715
# Document 48 - Similarity: 0.2509281214627602
# Document 1303 - Similarity: 0.2468752846242395
# Document 423 - Similarity: 0.23843219764057902
# Document 1308 - Similarity: 0.23647185365789827
# Document 999 - Similarity: 0.2151966270160114
# Document 63 - Similarity: 0.18532594389679063
# --------------------------------------------------
# Testing query: do viscous effects seriously modify pressure distributions .
# Document 147 - Similarity: 0.19692125541090733
# Document 310 - Similarity: 0.13730126233264983
# Document 305 - Similarity: 0.13522815560463516
# Document 937 - Similarity: 0.12789438148789858
# Document 1311 - Similarity: 0.12272436016864588
# Document 1080 - Similarity: 0.12238498561565667
# Document 443 - Similarity: 0.11901033019438606
# Document 1076 - Similarity: 0.10872196242433635
# Document 540 - Similarity: 0.10420864223253014
# Document 573 - Similarity: 0.10074110354001113
# --------------------------------------------------
# Testing query: has anyone investigated theoretically whether surface flexibility
# can stabilize a laminar boundary layer .
# Document 1321 - Similarity: 0.4424581071884904
# Document 1287 - Similarity: 0.38202315005863713
# Document 1197 - Similarity: 0.26393340387476705
# Document 1322 - Similarity: 0.22365084086481815
# Document 55 - Similarity: 0.22306941063909672
# Document 78 - Similarity: 0.1973975172690546
# Document 73 - Similarity: 0.17599853964734394
# Document 133 - Similarity: 0.15953691910140197
# Document 1076 - Similarity: 0.1578607993099892
# Document 959 - Similarity: 0.15739244789983883
# --------------------------------------------------
# Testing query: how do subsonic and transonic flutter data measured in the new langley
# transonic dynamics tunnel compare with similar data obtained in other
# facilities .
# Document 1290 - Similarity: 0.6209483355735161
# Document 879 - Similarity: 0.37200862140493524
# Document 1338 - Similarity: 0.3108899435023308
# Document 801 - Similarity: 0.26749722717088503
# Document 468 - Similarity: 0.2669262702877381
# Document 503 - Similarity: 0.26528490542725813
# Document 526 - Similarity: 0.26120095252407327
# Document 876 - Similarity: 0.24861017778785993
# Document 878 - Similarity: 0.24000568959820645
# Document 312 - Similarity: 0.23500812664589407
# --------------------------------------------------
# Testing query: how do large changes in new mass ratio quantitatively affect
# wing-flutter boundaries .
# Document 458 - Similarity: 0.20285240160675067
# Document 365 - Similarity: 0.1852765969982894
# Document 1185 - Similarity: 0.183559002677594
# Document 439 - Similarity: 0.17355539120563374
# Document 525 - Similarity: 0.16487413653118824
# Document 84 - Similarity: 0.15527457255072047
# Document 123 - Similarity: 0.14759943399346512
# Document 818 - Similarity: 0.13834007853018776
# Document 1188 - Similarity: 0.1337419279896235
# Document 925 - Similarity: 0.13316582990126435
# --------------------------------------------------
# Testing query: what is the effect of the shape of the drag polar of a lifting
# spacecraft on the amount of reduction in maximum deceleration obtainable by
# continuously varying the aerodynamic coefficients during re-entry .
# Document 1291 - Similarity: 0.5808860853081402
# Document 1344 - Similarity: 0.3371086119560268
# Document 566 - Similarity: 0.18750100542882556
# Document 1124 - Similarity: 0.14592940037601168
# Document 368 - Similarity: 0.14394235561561292
# Document 1256 - Similarity: 0.1380460471636817
# Document 163 - Similarity: 0.1361119062944328
# Document 1345 - Similarity: 0.13256800294307042
# Document 279 - Similarity: 0.1283232791073428
# Document 1380 - Similarity: 0.12357539544576868
# --------------------------------------------------
# Testing query: what are the physical significance and characteristics of separated
# laminar and turbulent boundary layer flows .
# Document 959 - Similarity: 0.42201763418516347
# Document 358 - Similarity: 0.32972394831240126
# Document 1228 - Similarity: 0.3257014154806472
# Document 996 - Similarity: 0.3239276024094519
# Document 798 - Similarity: 0.3078635168854728
# Document 240 - Similarity: 0.29207819940779783
# Document 1281 - Similarity: 0.26995599908091966
# Document 187 - Similarity: 0.26548005785105644
# Document 1383 - Similarity: 0.26372393540303224
# Document 55 - Similarity: 0.2610675736841673
# --------------------------------------------------
# Testing query: has anyone analytically investigated the stabilizing influence of soft
# elastic cores on the buckling strength of cylindrical shells subjected
# to non-uniform external pressure .
# Document 1172 - Similarity: 0.6623320218568821
# Document 1171 - Similarity: 0.5515018503466763
# Document 1145 - Similarity: 0.3861467589268186
# Document 1126 - Similarity: 0.30176035329017104
# Document 956 - Similarity: 0.27222700037766573
# Document 739 - Similarity: 0.26582909589171705
# Document 887 - Similarity: 0.26565084014333784
# Document 1068 - Similarity: 0.25960237221323457
# Document 889 - Similarity: 0.25813660221302126
# Document 740 - Similarity: 0.2561148434651651
# --------------------------------------------------
# Testing query: what papers are available on the buckling of empty cylindrical shells
# under non-uniform pressure .
# Document 739 - Similarity: 0.49939678985228886
# Document 897 - Similarity: 0.46812564908551846
# Document 740 - Similarity: 0.4580498559867235
# Document 887 - Similarity: 0.4348223990532807
# Document 741 - Similarity: 0.41463241696456155
# Document 886 - Similarity: 0.40077536058315727
# Document 889 - Similarity: 0.3980959826894503
# Document 1068 - Similarity: 0.39554286151275375
# Document 890 - Similarity: 0.39375081790266436
# Document 1126 - Similarity: 0.37754721707686156
# --------------------------------------------------
# Testing query: what effect do thermal stresses have on the compressive buckling
# strength of ring-stiffened cylinders .
# Document 642 - Similarity: 0.5369214508257846
# Document 1178 - Similarity: 0.531059808661764
# Document 888 - Similarity: 0.5126457491243229
# Document 1146 - Similarity: 0.47276308641604553
# Document 1177 - Similarity: 0.46610253843938254
# Document 885 - Similarity: 0.42342026007870115
# Document 31 - Similarity: 0.41944179099732953
# Document 1046 - Similarity: 0.37768052895775256
# Document 1045 - Similarity: 0.3683692833976844
# Document 887 - Similarity: 0.357713073391485
# --------------------------------------------------
# Testing query: what is the effect on cylinder buckling of a circumferential stress
# system that varies in the axial direction .
# Document 888 - Similarity: 0.49683393900940337
# Document 885 - Similarity: 0.42858640808778364
# Document 769 - Similarity: 0.4084348953596314
# Document 1146 - Similarity: 0.3743102932968498
# Document 741 - Similarity: 0.3600948486647972
# Document 1178 - Similarity: 0.32095104501934263
# Document 642 - Similarity: 0.3193708809243135
# Document 1116 - Similarity: 0.31465115109612085
# Document 891 - Similarity: 0.3095134424898339
# Document 887 - Similarity: 0.29683843987052233
# --------------------------------------------------
# Testing query: can non-linear shallow shell analysis be reduced to an engineering
# technique by use of the matrix .
# Document 1294 - Similarity: 0.5677222671056036
# Document 828 - Similarity: 0.4397712959097551
# Document 1362 - Similarity: 0.37528824484240275
# Document 831 - Similarity: 0.3308564668179541
# Document 930 - Similarity: 0.2671151970713664
# Document 1043 - Similarity: 0.2632753802458895
# Document 47 - Similarity: 0.25456760352838287
# Document 756 - Similarity: 0.24785974172245342
# Document 1042 - Similarity: 0.23645304144061768
# Document 1036 - Similarity: 0.23311719035417394
# --------------------------------------------------
# Testing query: is it possible to predict the shape of a shroud which will allow
# simulation of the nose region flow field for a sphere in hypersonic flow .
# Document 535 - Similarity: 0.46262358837317213
# Document 68 - Similarity: 0.2790552923928988
# Document 1234 - Similarity: 0.25638116172857056
# Document 1253 - Similarity: 0.24252792511339005
# Document 770 - Similarity: 0.2313034133674662
# Document 25 - Similarity: 0.2187357271081083
# Document 357 - Similarity: 0.21832636587541218
# Document 1205 - Similarity: 0.211461223025158
# Document 1204 - Similarity: 0.20022195421735933
# Document 44 - Similarity: 0.19599484415816823
# --------------------------------------------------
# Testing query: what investigations have been made of the wave system created by a
# static pressure distribution over a liquid surface .
# Document 764 - Similarity: 0.2172526381524093
# Document 407 - Similarity: 0.1895658203244265
# Document 958 - Similarity: 0.186528722653128
# Document 117 - Similarity: 0.1768197887090443
# Document 1225 - Similarity: 0.16665924761599804
# Document 974 - Similarity: 0.15785210766219895
# Document 1220 - Similarity: 0.15528691022407626
# Document 175 - Similarity: 0.15111509687941818
# Document 1269 - Similarity: 0.1457970979736473
# Document 1032 - Similarity: 0.13327623844014963
# --------------------------------------------------
# Testing query: has anyone investigated the effect of shock generated vorticity on heat
# transfer to a blunt body .
# Document 323 - Similarity: 0.3463344171754849
# Document 559 - Similarity: 0.3362735207374054
# Document 666 - Similarity: 0.32608579862274445
# Document 629 - Similarity: 0.31785072922400537
# Document 655 - Similarity: 0.31697905866322534
# Document 324 - Similarity: 0.30625909325758766
# Document 1319 - Similarity: 0.28664818025784045
# Document 1274 - Similarity: 0.2734480389390014
# Document 554 - Similarity: 0.2558762547081499
# Document 65 - Similarity: 0.24795583638345722
# --------------------------------------------------
# Testing query: what is the heat transfer to a blunt body in the absence of vorticity .
# Document 559 - Similarity: 0.27036319183995866
# Document 323 - Similarity: 0.2665059241434855
# Document 666 - Similarity: 0.24551670559664196
# Document 629 - Similarity: 0.24133596703407115
# Document 655 - Similarity: 0.23739956465376036
# Document 324 - Similarity: 0.223153869669073
# Document 180 - Similarity: 0.1950935417318122
# Document 398 - Similarity: 0.1813212338060231
# Document 554 - Similarity: 0.1753631238873976
# Document 1281 - Similarity: 0.17510778486353862
# --------------------------------------------------
# Testing query: what are the general effects on flow fields when the reynolds number is
# small .
# Document 1078 - Similarity: 0.3159323031580089
# Document 1222 - Similarity: 0.25108167396887343
# Document 668 - Similarity: 0.23543697029407176
# Document 1191 - Similarity: 0.2327217369328634
# Document 53 - Similarity: 0.21796662526525662
# Document 197 - Similarity: 0.2134599521724931
# Document 579 - Similarity: 0.20865786723186297
# Document 992 - Similarity: 0.20800029489901778
# Document 1221 - Similarity: 0.20484008802914724
# Document 342 - Similarity: 0.20266713222066296
# --------------------------------------------------
# Testing query: find a calculation procedure applicable to all incompressible laminar
# boundary layer flow problems having good accuracy and reasonable
# computation time .
# Document 738 - Similarity: 0.2629417114299257
# Document 4 - Similarity: 0.2503628057217561
# Document 292 - Similarity: 0.22727144286457873
# Document 629 - Similarity: 0.198744376758571
# Document 232 - Similarity: 0.19375618905007788
# Document 325 - Similarity: 0.18914704414090813
# Document 376 - Similarity: 0.18484194268022955
# Document 1192 - Similarity: 0.17675054859691222
# Document 461 - Similarity: 0.17206917883972309
# Document 231 - Similarity: 0.17150960146678704
# --------------------------------------------------
# Testing query: papers applicable to this problem (calculation procedures for laminar
# incompressible flow with arbitrary pressure gradient) .
# Document 1366 - Similarity: 0.32664775221501713
# Document 1386 - Similarity: 0.27922349835623583
# Document 1225 - Similarity: 0.2532502134137051
# Document 62 - Similarity: 0.23567444106518282
# Document 435 - Similarity: 0.22554131899460392
# Document 55 - Similarity: 0.22549682205096305
# Document 292 - Similarity: 0.223682891679265
# Document 4 - Similarity: 0.21341293840033473
# Document 54 - Similarity: 0.19686885728937528
# Document 754 - Similarity: 0.1924769154845726
# --------------------------------------------------
# Testing query: has anyone investigated the shear buckling of stiffened plates .
# Document 1400 - Similarity: 0.6607495013180646
# Document 1399 - Similarity: 0.6176447508285586
# Document 1398 - Similarity: 0.5400177230639741
# Document 1130 - Similarity: 0.5217501353371826
# Document 419 - Similarity: 0.5123275414781372
# Document 1396 - Similarity: 0.43057705202347757
# Document 1358 - Similarity: 0.42921526384989006
# Document 1397 - Similarity: 0.40014428678538366
# Document 1357 - Similarity: 0.3949956722149388
# Document 1116 - Similarity: 0.3499618781615515
# --------------------------------------------------
# Testing query: papers on shear buckling of unstiffened rectangular plates under shear .
# Document 400 - Similarity: 0.4067856613627269
# Document 1399 - Similarity: 0.35053473400704016
# Document 1398 - Similarity: 0.3293321351623243
# Document 393 - Similarity: 0.30225851748058896
# Document 4 - Similarity: 0.2924343418211036
# Document 664 - Similarity: 0.2684212695626849
# Document 1400 - Similarity: 0.25148692874931794
# Document 389 - Similarity: 0.2509688247113816
# Document 659 - Similarity: 0.24999111919735792
# Document 418 - Similarity: 0.24456554793487337
# --------------------------------------------------
# Testing query: in practice, how close to reality are the assumptions that the flow
# in a hypersonic shock tube using nitrogen is non-viscous and in
# thermodynamic equilibrium .
# Document 1312 - Similarity: 0.3300650137456169
# Document 236 - Similarity: 0.2958717142865551
# Document 1286 - Similarity: 0.2754681883841281
# Document 1298 - Similarity: 0.2675096200411377
# Document 1315 - Similarity: 0.24759255686222623
# Document 396 - Similarity: 0.2319379853398902
# Document 1314 - Similarity: 0.21841613445005043
# Document 656 - Similarity: 0.21137417224500016
# Document 175 - Similarity: 0.21038852859538074
# Document 110 - Similarity: 0.20961026546201908
# --------------------------------------------------
# Testing query: what design factors can be used to control lift-drag ratios at mach
# numbers above 5 .
# Document 748 - Similarity: 0.3331174459866616
# Document 368 - Similarity: 0.3320212069641245
# Document 1349 - Similarity: 0.2791048311092889
# Document 638 - Similarity: 0.26450277109408166
# Document 969 - Similarity: 0.25166764314693457
# Document 1188 - Similarity: 0.2499914518047023
# Document 451 - Similarity: 0.24261897102287455
# Document 1380 - Similarity: 0.22576428109700988
# Document 1163 - Similarity: 0.22229053143325986
# Document 1340 - Similarity: 0.17847918312406308
# --------------------------------------------------
